# %%
from rewardgym import GridWorldEnv

# %%
import gymnasium

# %%
env = GridWorldEnv(render_mode='human')

# %%
env.reset()
# Out:
# ({'agent': array([4, 4]), 'target': array([3, 3])}, {'distance': 2.0})

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /mrhome/simons/Desktop/rewardGym/rockbottom.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/mrhome/simons/Desktop/rewardGym/rockbottom.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> env.close()
#
# NameError: name 'env' is not defined
